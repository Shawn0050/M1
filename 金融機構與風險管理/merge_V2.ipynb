# %%
import pandas as pd

# 读取数据
financial_ratio = pd.read_csv('/Users/shawn/Github/M1/金融機構與風險管理/S_P500 財務比率.csv')
rating = pd.read_csv('/Users/shawn/Github/M1/金融機構與風險管理/rating.csv')

financial_ratio['datadate'] = pd.to_datetime(financial_ratio['datadate'], format='%Y/%m/%d')
financial_ratio['datadate'] = financial_ratio['datadate'].dt.strftime('%Y-%m-%d')


rating['datadate'] = pd.to_datetime(rating['datadate'], format='%Y-%m-%d')
rating['datadate'] = rating['datadate'].dt.strftime('%Y-%m-%d')

# %%
merged_df = pd.merge(financial_ratio, rating[['datadate', 'ticker', 'splticrm']], on=['datadate', 'ticker'], how='left')
merged_df['splticrm']


print(merged_df[merged_df['ticker'] == 'AMD'][['datadate','ticker','splticrm']].head()) 
print(rating[rating['ticker'] == 'AMD'][['datadate','ticker','splticrm']].head())
# Out:
#          datadate ticker splticrm
# 31998  2010-01-31    AMD       B-
# 31999  2010-02-28    AMD       B-
# 32000  2010-03-31    AMD       B-
# 32001  2010-04-30    AMD       B-
# 32002  2010-05-31    AMD       B-
#        datadate ticker splticrm
# 388  2001-01-31    AMD        B
# 389  2001-02-28    AMD        B
# 390  2001-03-31    AMD        B
# 391  2001-04-30    AMD        B
# 392  2001-05-31    AMD        B

# %%
# financial_ratio, rating期間範圍無對齊
merged_df.dropna(subset=['splticrm'], inplace=True)
def filter_rows(group):
    # 組內rating前後不同的才會被留下
    mask = group['splticrm'] != group['splticrm'].shift()
    return group[mask]
merged_df = merged_df.groupby('ticker').apply(filter_rows).reset_index(drop=True)
merged_df['ticker'].value_counts().to_frame()
# Out:
#         count
# ticker
# CHK        12
# AKS         7
# ETFC        7
# M           7
# DO          7
# ...       ...
# JNJ         1
# KEY         1
# KMB         1
# KR          1
# JNPR        1
#
# [315 rows x 1 columns]

# %%
# merged_df保留了所有ticker
merged_df2 = merged_df.groupby('ticker').filter(lambda x: len(x) > 1)
print(merged_df2['ticker'].value_counts().to_frame())
print(len(merged_df2))
merged_df2.to_csv('SP500_merge.csv')
merged_df2.head()
# Out:
#         count
# ticker
# CHK        12
# ETFC        7
# DO          7
# AKS         7
# M           7
# ...       ...
# OKE         2
# D           2
# ODP         2
# DD          2
# PEG         2
#
# [225 rows x 1 columns]
# 668
#    gvkey  permno       adate       qdate    datadate   CAPEI     bm     evm  \
# 1   1078   20482  2008/12/31   2009/9/30  2010-01-31  23.252  0.279  10.335
# 2   1078   20482  2011/12/31   2012/6/30  2012-10-31  22.742  0.242  11.602
# 3   1078   20482  2015/12/31   2016/9/30  2017-01-31  35.311  0.334  14.313
# 4  12540   75510  2009/11/30  2009/11/30  2010-01-31  27.386  0.281  19.497
# 5  12540   75510  2012/11/30   2013/8/31  2013-12-31  42.614  0.312  22.531
#
#    pe_op_basic  pe_op_dil  ...  rd_sale  adv_sale  staff_sale  accrual    ptb  \
# 1       14.584     14.706  ...    0.091     0.000         0.0   -0.031  3.838
# 2       20.092     20.342  ...    0.115     0.000         0.0   -0.099  4.198
# 3       24.145     24.285  ...    0.070     0.000         0.0   -0.046  3.460
# 4       40.886     41.410  ...    0.192     0.023         0.0   -0.112  3.292
# 5       64.386     65.801  ...    0.196     0.023         0.0   -0.086  4.148
#
#    PEG_trailing  divyield  ticker     cusip  splticrm
# 1         0.370     3.02%     ABT    282410        AA
# 2           NaN     3.11%     ABT    282410        A+
# 3         2.802     2.54%     ABT    282410       BBB
# 4         5.746       NaN    ADBE  00724F10      BBB+
# 5         4.301       NaN    ADBE  00724F10        A-
#
# [5 rows x 77 columns]

# %%
ratings_map = {
    'D': 0, 'CC': 1, 'CCC': 2, 'CCC+': 3,
    'B-': 4, 'B': 5, 'B+': 6, 'BB-': 7, 'BB': 8, 'BB+': 9,
    'BBB-': 10, 'BBB': 11, 'BBB+': 12,
    'A-': 13, 'A': 14, 'A+': 15, 'AA-': 16, 'AA': 17, 'AA+': 18, 'AAA': 19
}

# 將評級參數化
merged_df2['rating'] = merged_df2['splticrm'].map(ratings_map)
merged_df2.head()
# Out:
#    gvkey  permno       adate       qdate    datadate   CAPEI     bm     evm  \
# 1   1078   20482  2008/12/31   2009/9/30  2010-01-31  23.252  0.279  10.335
# 2   1078   20482  2011/12/31   2012/6/30  2012-10-31  22.742  0.242  11.602
# 3   1078   20482  2015/12/31   2016/9/30  2017-01-31  35.311  0.334  14.313
# 4  12540   75510  2009/11/30  2009/11/30  2010-01-31  27.386  0.281  19.497
# 5  12540   75510  2012/11/30   2013/8/31  2013-12-31  42.614  0.312  22.531
#
#    pe_op_basic  pe_op_dil  ...  adv_sale  staff_sale  accrual    ptb  \
# 1       14.584     14.706  ...     0.000         0.0   -0.031  3.838
# 2       20.092     20.342  ...     0.000         0.0   -0.099  4.198
# 3       24.145     24.285  ...     0.000         0.0   -0.046  3.460
# 4       40.886     41.410  ...     0.023         0.0   -0.112  3.292
# 5       64.386     65.801  ...     0.023         0.0   -0.086  4.148
#
#    PEG_trailing  divyield  ticker     cusip  splticrm  rating
# 1         0.370     3.02%     ABT    282410        AA      17
# 2           NaN     3.11%     ABT    282410        A+      15
# 3         2.802     2.54%     ABT    282410       BBB      11
# 4         5.746       NaN    ADBE  00724F10      BBB+      12
# 5         4.301       NaN    ADBE  00724F10        A-      13
#
# [5 rows x 78 columns]

# %%
def process_data(group):
    # 保留前一期的評價
    group['prev_rating'] = group['rating'].shift(1)
    group['rating_diff'] = group['rating'] - group['rating'].shift(1)
    # 變化率
    for col in group.columns:
        if pd.api.types.is_numeric_dtype(group[col]):
            group[col + '_change'] = group[col].pct_change()

    # 刪除前一期評價(prev_rating)
    # group = group[group['is_upgraded'] == 1].drop(columns=['prev_rating'])
    group = group.dropna(subset=['prev_rating'])

    return group

# %%
merged_df3 = merged_df2.groupby('ticker').apply(process_data).reset_index(drop=True)
merged_df3[['ticker','prev_rating','splticrm','rating_diff']].head()
merged_df3.head()
# Out:
#    gvkey  permno       adate      qdate    datadate   CAPEI     bm     evm  \
# 0   1078   20482  2011/12/31  2012/6/30  2012-10-31  22.742  0.242  11.602
# 1   1078   20482  2015/12/31  2016/9/30  2017-01-31  35.311  0.334  14.313
# 2  12540   75510  2012/11/30  2013/8/31  2013-12-31  42.614  0.312  22.531
# 3   1632   60871  2009/10/31  2010/7/31  2010-09-30  20.402  0.346   9.867
# 4   1632   60871  2015/10/31  2016/4/30  2016-07-31  28.032  0.289  15.494
#
#    pe_op_basic  pe_op_dil  ...  sale_nwc_change  rd_sale_change  \
# 0       20.092     20.342  ...        -0.145647        0.263736
# 1       24.145     24.285  ...         0.270724       -0.391304
# 2       64.386     65.801  ...        -0.232854        0.020833
# 3       15.458     15.769  ...         0.108559       -0.166667
# 4       21.935     22.240  ...        -0.091337        0.032432
#
#    adv_sale_change  staff_sale_change  accrual_change  ptb_change  \
# 0              NaN                NaN        2.193548    0.093799
# 1              NaN                NaN       -0.535354   -0.175798
# 2         0.000000                NaN       -0.232143    0.260024
# 3         0.000000                NaN        0.368421   -0.004239
# 4        -0.666667                NaN       -0.500000    0.285527
#
#    PEG_trailing_change  rating_change  prev_rating_change  rating_diff_change
# 0             0.000000      -0.117647                 NaN                 NaN
# 1             6.572973      -0.266667           -0.117647                 1.0
# 2            -0.251479       0.083333                 NaN                 NaN
# 3                  NaN       0.083333                 NaN                 NaN
# 4             0.000000      -0.153846            0.083333                -3.0
#
# [5 rows x 153 columns]

# %%
merged_df3 = merged_df3.drop(columns=['gvkey','permno','adate','qdate','rating_diff_change','prev_rating_change','rating_change'])
merged_df3.to_csv('/Users/shawn/Github/M1/金融機構與風險管理/SP500_change_V2.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/shawn/Github/M1/金融機構與風險管理/merge_V2.ipynb 儲存格 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/shawn/Github/M1/%E9%87%91%E8%9E%8D%E6%A9%9F%E6%A7%8B%E8%88%87%E9%A2%A8%E9%9A%AA%E7%AE%A1%E7%90%86/merge_V2.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> merged_df3 = merged_df3.drop(columns=['gvkey','permno','adate','qdate','rating_diff_change','prev_rating_change','rating_change'])
#       <a href='vscode-notebook-cell:/Users/shawn/Github/M1/%E9%87%91%E8%9E%8D%E6%A9%9F%E6%A7%8B%E8%88%87%E9%A2%A8%E9%9A%AA%E7%AE%A1%E7%90%86/merge_V2.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> merged_df3.to_csv('/Users/shawn/Github/M1/金融機構與風險管理/SP500_change_V2.csv')
#       <a href='vscode-notebook-cell:/Users/shawn/Github/M1/%E9%87%91%E8%9E%8D%E6%A9%9F%E6%A7%8B%E8%88%87%E9%A2%A8%E9%9A%AA%E7%AE%A1%E7%90%86/merge_V2.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> merged_df3
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['gvkey', 'permno', 'adate', 'qdate', 'rating_diff_change', 'prev_rating_change', 'rating_change'] not found in axis"

# %%
merged_df3
# Out:
#        datadate   CAPEI     bm     evm  pe_op_basic  pe_op_dil  pe_exi  \
# 0    2012-10-31  22.742  0.242  11.602       20.092     20.342  38.988
# 1    2017-01-31  35.311  0.334  14.313       24.145     24.285  63.288
# 2    2013-12-31  42.614  0.312  22.531       64.386     65.801  68.044
# 3    2010-09-30  20.402  0.346   9.867       15.458     15.769  16.092
# 4    2016-07-31  28.032  0.289  15.494       21.935     22.240  31.137
# ..          ...     ...    ...     ...          ...        ...     ...
# 438  2010-09-30  20.735  0.408  11.793       17.005     17.281  17.188
# 439  2011-09-30  16.648  0.395  12.316       15.269     15.579  16.068
# 440  2010-02-28  10.209  0.959   8.901       15.361     15.361  17.036
# 441  2013-12-31  17.661  0.951   6.128       49.172     50.186  52.913
# 442  2016-01-31   9.221  0.925   7.609       44.828     45.349  79.592
#
#       pe_inc     ps     pcf  ...  pay_turn_change  sale_invcap_change  \
# 0     21.405  3.338  11.751  ...        -0.281429           -0.167503
# 1     45.901  3.472  25.128  ...         0.216032           -0.073494
# 2     68.044  7.131  22.677  ...         0.602543            0.002000
# 3     16.092  3.649  10.635  ...         0.239008            0.160173
# 4     31.137  5.789  20.990  ...        -0.072770           -0.310945
# ..       ...    ...     ...  ...              ...                 ...
# 438   17.188  2.055  11.426  ...        -0.027884           -0.025490
# 439   16.068  1.895  11.516  ...         0.034565           -0.109658
# 440   17.036  0.537   3.692  ...        -0.115104           -0.142077
# 441   52.344  0.729   4.712  ...         0.350531            0.142251
# 442  130.000  0.532   6.208  ...         0.038336            0.035316
#
#      sale_equity_change  sale_nwc_change  rd_sale_change  adv_sale_change  \
# 0             -0.203585        -0.145647        0.263736              NaN
# 1             -0.201768         0.270724       -0.391304              NaN
# 2              0.016611        -0.232854        0.020833         0.000000
# 3              0.146801         0.108559       -0.166667         0.000000
# 4             -0.258206        -0.091337        0.032432        -0.666667
# ..                  ...              ...             ...              ...
# 438           -0.004026        -0.206382       -0.115385              NaN
# 439           -0.029911        -0.264997       -0.043478              NaN
# 440           -0.097275        -0.438268       -0.129630              NaN
# 441           -0.207153         2.061806       -0.361702              NaN
# 442            0.049209        -0.080177        0.033333              NaN
#
#      staff_sale_change  accrual_change  ptb_change  PEG_trailing_change
# 0                  NaN        2.193548    0.093799             0.000000
# 1                  NaN       -0.535354   -0.175798             6.572973
# 2                  NaN       -0.232143    0.260024            -0.251479
# 3                  NaN        0.368421   -0.004239                  NaN
# 4                  NaN       -0.500000    0.285527             0.000000
# ..                 ...             ...         ...                  ...
# 438                NaN        0.576923    0.003865             2.253028
# 439                NaN       -0.243902   -0.212938             3.519239
# 440                NaN        0.480000    0.051865                  NaN
# 441                NaN       -0.081081    0.076125             0.452511
# 442                NaN       -0.441176   -0.129421             0.000000
#
# [443 rows x 146 columns]

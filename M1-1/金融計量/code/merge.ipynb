# %% [markdown]
# ## Merge all stock portfolios

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
@author: shawn
"""
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms

df = pd.read_csv('/Users/shawn/Github/M1/金融計量/TWstocks.csv')
df.head()

df['帳面市值比'] = 1/df['股價淨值比-TEJ']
# ME = df.groupby('年月')['市值(百萬元)'].apply(lambda x: x.median())
# ME.name = '市值_中位數'
# df = df.merge(ME, on='年月')
# df['市值matrix'] = np.where(df['市值(百萬元)']>df['市值_中位數'], 'B', 'S')
df['市值分組'] = df.groupby('年月')['市值(百萬元)'].transform(lambda x: pd.qcut(x, q=5, labels=['ME1', 'ME2', 'ME3', 'ME4', 'ME5']))
df['帳面市值比分組'] = df.groupby('年月')['帳面市值比'].transform(lambda x: pd.qcut(x, q=5, labels=['BM1', 'BM2', 'BM3', 'BM4', 'BM5']))

df['size_bm'] = np.where((df['市值分組'] == 'ME1') & (df['帳面市值比分組'] == 'BM1'), 'ME1_BM1',
                np.where((df['市值分組'] == 'ME1') & (df['帳面市值比分組'] == 'BM2'), 'ME1_BM2',
                np.where((df['市值分組'] == 'ME1') & (df['帳面市值比分組'] == 'BM3'), 'ME1_BM3',
                np.where((df['市值分組'] == 'ME1') & (df['帳面市值比分組'] == 'BM4'), 'ME1_BM4',
                np.where((df['市值分組'] == 'ME1') & (df['帳面市值比分組'] == 'BM5'), 'ME1_BM5',
                np.where((df['市值分組'] == 'ME2') & (df['帳面市值比分組'] == 'BM1'), 'ME2_BM1',
                np.where((df['市值分組'] == 'ME2') & (df['帳面市值比分組'] == 'BM2'), 'ME2_BM2',
                np.where((df['市值分組'] == 'ME2') & (df['帳面市值比分組'] == 'BM3'), 'ME2_BM3',
                np.where((df['市值分組'] == 'ME2') & (df['帳面市值比分組'] == 'BM4'), 'ME2_BM4',
                np.where((df['市值分組'] == 'ME2') & (df['帳面市值比分組'] == 'BM5'), 'ME2_BM5',
                np.where((df['市值分組'] == 'ME3') & (df['帳面市值比分組'] == 'BM1'), 'ME3_BM1',
                np.where((df['市值分組'] == 'ME3') & (df['帳面市值比分組'] == 'BM2'), 'ME3_BM2',
                np.where((df['市值分組'] == 'ME3') & (df['帳面市值比分組'] == 'BM3'), 'ME3_BM3',
                np.where((df['市值分組'] == 'ME3') & (df['帳面市值比分組'] == 'BM4'), 'ME3_BM4',
                np.where((df['市值分組'] == 'ME3') & (df['帳面市值比分組'] == 'BM5'), 'ME3_BM5',
                np.where((df['市值分組'] == 'ME4') & (df['帳面市值比分組'] == 'BM1'), 'ME4_BM1',
                np.where((df['市值分組'] == 'ME4') & (df['帳面市值比分組'] == 'BM2'), 'ME4_BM2',
                np.where((df['市值分組'] == 'ME4') & (df['帳面市值比分組'] == 'BM3'), 'ME4_BM3',
                np.where((df['市值分組'] == 'ME4') & (df['帳面市值比分組'] == 'BM4'), 'ME4_BM4',
                np.where((df['市值分組'] == 'ME4') & (df['帳面市值比分組'] == 'BM5'), 'ME4_BM5',
                np.where((df['市值分組'] == 'ME5') & (df['帳面市值比分組'] == 'BM1'), 'ME5_BM1',
                np.where((df['市值分組'] == 'ME5') & (df['帳面市值比分組'] == 'BM2'), 'ME5_BM2',
                np.where((df['市值分組'] == 'ME5') & (df['帳面市值比分組'] == 'BM3'), 'ME5_BM3',
                np.where((df['市值分組'] == 'ME5') & (df['帳面市值比分組'] == 'BM4'), 'ME5_BM4',
                np.where((df['市值分組'] == 'ME5') & (df['帳面市值比分組'] == 'BM5'), 'ME5_BM5',
                         ''))))))))))))))))))))))))) # 如果沒有符合的條件，給予 NaN

df.drop(df[df['size_bm'] == ''].index, inplace=True)
df.head()


df.to_csv('/Users/shawn/Github/M1/金融計量/test.csv')

weighted_returns = df.groupby(['年月', 'size_bm']).apply(lambda x: (x['報酬率％_月'] * x['市值(百萬元)']).sum() / x['市值(百萬元)'].sum()).reset_index()
weighted_returns.columns = ['date', 'portf', 'ExRet']

weighted_returns

weighted_returns = weighted_returns.pivot(index='date', columns='portf', values='ExRet')
weighted_returns

# result_df.to_csv('/Users/shawn/Github/M1/金融計量/25_Size_BM.csv')
# Out:
# portf     ME1_BM1    ME1_BM2    ME1_BM3    ME1_BM4   ME1_BM5    ME2_BM1  \
# date
# 201001  32.890875  -4.695570  -8.750316  -8.279946 -5.332219  -3.561119
# 201002   0.461274  -6.456261  -0.365751  -3.706888 -1.921799   4.965301
# 201003   8.010449  15.595326  16.829004  11.374620  9.151004  17.013821
# 201004   9.335599  -1.397550   6.335519   4.250821  4.553978   3.237774
# 201005 -10.396295  -2.172570  -8.820830  -8.777200 -7.532012  -6.222561
# ...           ...        ...        ...        ...       ...        ...
# 202308  14.557165  -0.850011  -0.156880  -1.426551 -3.604449   0.736321
# 202309   5.051835  -0.836928   0.763077  -0.893305  0.217345  -2.863591
# 202310  -2.909976  -5.554652  -1.611277  -2.235559 -2.517852  -1.189402
# 202311   4.821762   6.011044   9.187815   8.033007  4.574634  15.579431
# 202312  -2.566611   0.593421   1.705303   1.413899  1.010008  -1.831937
#
# portf     ME2_BM2    ME2_BM3    ME2_BM4    ME2_BM5  ...    ME4_BM1    ME4_BM2  \
# date                                                ...
# 201001  -6.206268  -8.363253  -6.089003  -6.524916  ...  -9.094658  -7.414896
# 201002   0.281530  -0.301325  -2.389591  -4.198519  ...  -1.012413  -2.748699
# 201003  13.654096  14.652281  10.992721   8.537164  ...  13.410443  11.032410
# 201004   8.009871   0.927501   1.876041   0.091638  ...   1.882787   2.095164
# 201005  -7.443623 -11.024121  -8.652532 -10.632070  ...  -7.716726  -6.881043
# ...           ...        ...        ...        ...  ...        ...        ...
# 202308  -3.556921  -6.560576  -1.825461  -3.469404  ...  -1.729865  -0.491141
# 202309   1.759109   1.297324   1.355087  -0.574739  ...   2.708116   1.199242
# 202310  -1.284320   1.866707  -3.311658  -0.983407  ...  -4.408733  -2.542426
# 202311   8.158916   8.723350   7.431845   6.232264  ...  14.352065  11.118688
# 202312   1.456862   0.785166   2.161448   2.317675  ...  -0.509949  -0.141193
#
# portf    ME4_BM3    ME4_BM4   ME4_BM5    ME5_BM1   ME5_BM2   ME5_BM3  \
# date
# 201001 -5.943013  -5.977922 -8.179228  -6.186834 -2.092595 -5.602656
# 201002 -4.571871  -3.777080 -2.495989  -2.822378  1.146516 -4.685273
# 201003  8.539586   8.267648  8.199345   7.165132  1.894917  5.862600
# 201004  2.166175  -1.823111  0.449869   2.688093  0.879703  2.068281
# 201005 -9.721227 -10.950684 -8.869110  -5.924697 -7.187865 -6.917847
# ...          ...        ...       ...        ...       ...       ...
# 202308  2.001804   2.071255 -2.987260  -1.963964 -1.894873 -2.223568
# 202309  0.234765  -1.074088 -1.053402  -2.677368  0.082486  1.644722
# 202310 -3.232488  -2.321728 -2.953364  -0.503581 -3.152601 -1.717375
# 202311  7.405221   7.489866  5.865345  10.540287  7.505409  8.430866
# 202312  0.715077   1.071283  1.949633   2.298384  3.594205  2.144609
#
# portf    ME5_BM4   ME5_BM5
# date
# 201001 -7.959870 -8.790981
# 201002 -3.489328 -3.885512
# 201003  5.690239  8.779601
# 201004 -0.033417 -0.401744
# 201005 -9.152587 -7.581057
# ...          ...       ...
# 202308 -2.764339 -3.847808
# 202309 -1.052130  0.063900
# 202310 -2.340082 -4.494596
# 202311  8.570466  5.376052
# 202312  1.200289  4.833719
#
# [168 rows x 25 columns]

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
@author: shawn
"""
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms



df = pd.read_csv('/Users/shawn/Github/M1/金融計量/TWstocks.csv')
df.head()


df['market_cap_sorted'] = df.groupby('年月')['市值(百萬元)'].transform(lambda x: pd.qcut(x, q=10, labels=['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10']))


df.drop(df[df['market_cap_sorted'] == ''].index, inplace=True)
df.head()



weighted_returns2 = df.groupby(['年月', 'market_cap_sorted']).apply(lambda x: (x['報酬率％_月'] * x['市值(百萬元)']).sum() / x['市值(百萬元)'].sum()).reset_index()
weighted_returns2.columns = ['date', 'portf', 'ExRet']


weighted_returns2 = weighted_returns2.pivot(index='date', columns='portf', values='ExRet')
weighted_returns2
# Out:
# portf          q1         q2         q3         q4         q5         q6  \
# date
# 201001  -2.264849  -6.437285  -8.296804  -4.997506  -7.932275  -9.722709
# 201002  -1.701972  -2.860702  -0.483736  -0.917506  -2.058160  -0.909504
# 201003  11.642530  12.690145  12.643333  12.949478  11.109058  11.685387
# 201004   5.401096   3.947057   2.328018   3.088675   1.511558   0.254254
# 201005  -9.384219  -6.514104  -9.925066  -8.175461  -8.083272  -9.895033
# ...           ...        ...        ...        ...        ...        ...
# 202308  -2.523296  -0.068937  -2.340686  -3.901179  -1.590143  -3.095781
# 202309  -0.184798   0.274205   0.675675   0.377878   1.011442   0.630239
# 202310  -2.419347  -2.726660  -0.182091  -1.460137  -2.252726  -3.583913
# 202311   5.548351   7.752075   7.361149   9.877273  11.103797   8.556867
# 202312   1.224868   0.849907   2.144855   0.586824   1.344876   0.467620
#
# portf          q7         q8         q9       q10
# date
# 201001  -6.610153  -8.120098  -6.408804 -5.456440
# 201002  -1.424251  -3.569723  -4.069000 -2.187984
# 201003  11.677471   9.519990   8.712207  5.221342
# 201004   1.422132   1.428737   1.802785  1.627138
# 201005  -7.950852  -8.721672  -7.460651 -6.770519
# ...           ...        ...        ...       ...
# 202308  -1.839347   0.550902  -1.679048 -2.299595
# 202309  -0.521626   1.409000   0.953025 -1.698787
# 202310  -3.039549  -3.320215  -3.569424 -1.266629
# 202311   9.392672  10.369305  10.607960  9.084072
# 202312   1.097020   0.068645   1.576679  2.650339
#
# [168 rows x 10 columns]

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
@author: shawn
"""
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms



df = pd.read_csv('/Users/shawn/Github/M1/金融計量/TWstocks.csv')
df.head()


df['帳面市值比'] = 1/df['股價淨值比-TEJ']


df['bm_sorted'] = df.groupby('年月')['帳面市值比'].transform(lambda x: pd.qcut(x, q=10, labels=['bm1', 'bm2', 'bm3', 'bm4', 'bm5', 'bm6', 'bm7', 'bm8', 'bm9', 'bm10']))


df


df.drop(df[df['bm_sorted'] == ''].index, inplace=True)
df.head()


weighted_returns3 = df.groupby(['年月', 'bm_sorted']).apply(lambda x: (x['報酬率％_月'] * x['市值(百萬元)']).sum() / x['市值(百萬元)'].sum()).reset_index()
weighted_returns3.columns = ['date', 'portf', 'ExRet']


weighted_returns3 = weighted_returns3.pivot(index='date', columns='portf', values='ExRet')
weighted_returns3
# Out:
# portf         bm1        bm2       bm3       bm4       bm5       bm6  \
# date
# 201001  -5.027228  -8.424896 -6.732658 -1.436506 -4.770209 -8.365229
# 201002  -2.426740  -3.014030  1.763838 -0.875661 -4.521193 -3.844191
# 201003   7.819233   7.781354  3.888791  3.212918  8.136377  6.613820
# 201004   0.861420   6.434448  0.224513  2.129265  1.795063  2.279480
# 201005  -2.652358 -12.591204 -6.327463 -7.744850 -6.884849 -8.734748
# ...           ...        ...       ...       ...       ...       ...
# 202308  -1.707663  -3.161076 -0.783905 -3.475925 -2.219517 -1.423077
# 202309  -3.108415   0.454384  0.889020 -0.341851  1.963255  0.502679
# 202310  -1.027793   0.917107 -3.473666 -2.071393 -0.679304 -3.269331
# 202311  10.303171  13.140327  7.489250  9.580910  8.503395  8.111597
# 202312   2.039080   2.967933 -0.109854  6.699661  1.349080  2.397972
#
# portf         bm7       bm8       bm9      bm10
# date
# 201001  -8.341692 -7.097961 -8.389895 -7.958640
# 201002  -4.005428 -2.639724 -1.934897 -5.710806
# 201003   6.342818  6.899869  8.585533  8.926918
# 201004  -0.022408  0.224053  0.023982 -0.191450
# 201005  -9.248592 -9.427231 -8.152392 -8.577374
# ...           ...       ...       ...       ...
# 202308  -2.599828 -2.147927 -3.136239 -4.088283
# 202309  -0.690748 -1.110708 -1.071185  0.777541
# 202310  -2.048929 -2.704947 -4.127151 -4.010835
# 202311  10.368458  6.985847  6.188581  4.501508
# 202312   1.312054  1.200335  1.089851  8.875138
#
# [168 rows x 10 columns]

# %%
# 合并 df1 和 df2
merged_df = weighted_returns.merge(weighted_returns2, on='date', how='right')

# %%
merged_df = merged_df.merge(weighted_returns3, on='date', how='right')
merged_df
# Out:
# portf     ME1_BM1    ME1_BM2    ME1_BM3    ME1_BM4   ME1_BM5    ME2_BM1  \
# date
# 201001  32.890875  -4.695570  -8.750316  -8.279946 -5.332219  -3.561119
